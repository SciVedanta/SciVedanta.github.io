# %%
#pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_text(youtube_id="XhKdu1_m-k4"):
    try:
        text = " ".join(
            [
                i["text"]
                .replace("\xa0\xa0", " ")
                .replace("\n", "")
                .replace("\xa0", " ")
                for i in YouTubeTranscriptApi.get_transcript(youtube_id)
            ]
        )
        return text
    except:
        print ('Failed for',youtube_id )
        pass

# %%
import pandas as pd
df = pd.read_csv('Sheet1.csv')
df = df[df['Title'].notnull()]

# %%
df['youtube_id']=df['ID'].apply(lambda x: str(x).split('&')[0].strip('!'))

# %%
from tqdm import tqdm
tqdm.pandas()
df['text'] = df['youtube_id'].progress_apply(lambda x:get_text(x))
# Out:
#   7%|███████████▉                                                                                                                                                                   | 3/44 [00:01<00:26,  1.57it/s]
# Failed for MmoxzLIzAas
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:53<00:00,  1.21s/it]

# %%
df
# Out:
#                                                 Title  \
# 0   1. Katha Upanishad | Introduction | Swami Sarv...
# 1   2. Katha Upanishad | Mantras 1.1.1 - 3 | Swami...
# 2   3. Katha Upanishad | Mantras 1.1.4 - 8 | Swami...
# 3   4. Katha Upanishad | Mantras 1.1.9 - 11 | Swam...
# 4   5. Katha Upanishad | Mantras 1.1.12 - 15 | Swa...
# 5   6. Katha Upanishad | Mantras 1.1.16 - 19 | Swa...
# 6   7. Katha Upanishad | Mantra 1.1.20 | Swami Sar...
# 7   8. Katha Upanishad | Mantras 1.1.21 - 24 | Swa...
# 8   9. Katha Upanishad | Mantras 1.1.25 - 28 | Swa...
# 9   10. Katha Upanishad | Mantras 1.1.29 - 1.2.2 |...
# 10  11. Katha Upanishad | Mantras 1.2.3 - 5 | Swam...
# 11  12. Katha Upanishad | Mantras 1.2.6 - 7 | Swam...
# 12  13. Katha Upanishad | Mantras 1.2.8 - 10 | Swa...
# 13  14. Katha Upanishad | Mantras 1.2.11 - 13 | Sw...
# 14  15. Katha Upanishad | Mantras 1.2.14 - 15 | Sw...
# 15  16. Katha Upanishad | Mantras 1.2.16 - 19 | Sw...
# 16  17. Katha Upanishad | Mantra 1.2.20 | Swami Sa...
# 17  18. Katha Upanishad | Mantras 1.2.21 - 22 | Sw...
# 18  19. Katha Upanishad | Mantras 1.2.23 - 25 | Sw...
# 19  20. Katha Upanishad | Mantra 1.3.1 | Swami Sar...
# 20  21. Katha Upanishad | Mantras 1.3.2 - 9 | Swam...
# 21  22. Katha Upanishad | Mantras 1.3.10 - 12 | Sw...
# 22  23. Katha Upanishad | Mantra 1.3.13 | Swami Sa...
# 23  24. Katha Upanishad | Mantras 1.3.14 - 17 | Sw...
# 24  25. Katha Upanishad | Mantras 2.1.1 - 2 | Swam...
# 25  26. Katha Upanishad | Mantra 2.1.3 | Swami Sar...
# 26  27. Katha Upanishad | Mantras 2.1.4 - 5 | Swam...
# 27  28. Katha Upanishad | Mantras 2.1.6 - 9 | Swam...
# 28  29. Katha Upanishad | Mantra 2.1.10 | Swami Sa...
# 29  30. Katha Upanishad | Mantras 2.1.11 - 12 | Sw...
# 30  31. Katha Upanishad | Mantras 2.1.13 - 15 | Sw...
# 31  32. Katha Upanishad | Mantra 2.2.1 | Swami Sar...
# 32  33. Katha Upanishad | Mantras 2.2.2 - 4 | Swam...
# 33  34. Katha Upanishad | Mantras 2.2.5 - 8 | Swam...
# 34  35. Katha Upanishad | Mantras 2.2.9 - 11 | Swa...
# 35  36. Katha Upanishad | Mantras 2.2.12 | Swami S...
# 36  37. Katha Upanishad | Mantras 2.2.13 - 14 | Sw...
# 37  38. Katha Upanishad | Mantra 2.2.15 | Swami Sa...
# 38  39. Katha Upanishad | Mantra 2.3.1 | Swami Sar...
# 39  40. Katha Upanishad | Mantras 2.3.2 - 5 | Swam...
# 40  41. Katha Upanishad | Mantras 2.3.6 - 8 | Swam...
# 41  42. Katha Upanishad | Mantras 2.3.9 - 11 | Swa...
# 42  43. Katha Upanishad | Mantras 2.3.12 - 13 | Sw...
# 43  44. Katha Upanishad | Mantras 2.3.14 - 18 | Sw...
#
#                                                    ID   youtube_id  \
# 0   T9LqW5m0K4U&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  T9LqW5m0K4U
# 1   MmoxzLIzAas&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  MmoxzLIzAas
# 2   JFqfXk67D_0&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  JFqfXk67D_0
# 3   4IO1SO43nfg&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  4IO1SO43nfg
# 4   1Of2oh_V1uc&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  1Of2oh_V1uc
# 5   7rOdP6Y_WXo&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  7rOdP6Y_WXo
# 6   Ns7h-YLQ3wk&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  Ns7h-YLQ3wk
# 7   rz-b9rjSgV0&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  rz-b9rjSgV0
# 8   VJ2g3HSYK6E&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  VJ2g3HSYK6E
# 9   a6AF3i3mUUY&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  a6AF3i3mUUY
# 10  b_GLlrRi4y4&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  b_GLlrRi4y4
# 11  lxP7Sdxkm8M&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  lxP7Sdxkm8M
# 12  EmHNM-kdtSE&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  EmHNM-kdtSE
# 13  ZoNSg5-EZ0o&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  ZoNSg5-EZ0o
# 14  OKeFEGeZvFU&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  OKeFEGeZvFU
# 15  ScQlJIAJnFQ&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  ScQlJIAJnFQ
# 16  DHH8K5kzmLM&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  DHH8K5kzmLM
# 17  UamLcnY7Vkg&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  UamLcnY7Vkg
# 18  Nzp1OSonylQ&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  Nzp1OSonylQ
# 19  FaxMHzGoYBA&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  FaxMHzGoYBA
# 20  MaIjltvzKZA&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  MaIjltvzKZA
# 21  et3rpgF7RRY&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  et3rpgF7RRY
# 22  5iV2kikzo8Q&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  5iV2kikzo8Q
# 23  aJZn4GNEw8g&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  aJZn4GNEw8g
# 24  ofBUalNIjCc&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  ofBUalNIjCc
# 25  uVgATUq4eNQ&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  uVgATUq4eNQ
# 26  hUu70jpYvxk&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  hUu70jpYvxk
# 27  BE2_W30DnXA&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  BE2_W30DnXA
# 28  CgK2ETuzGRM&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  CgK2ETuzGRM
# 29  lAtBgu5s6Lw&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  lAtBgu5s6Lw
# 30  oZYeD4JWPyQ&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  oZYeD4JWPyQ
# 31  41Qd77ibOiY&list=PLDqahtm2vA72naWj1foEqGFQiN_b...  41Qd77ibOiY
# 32  s9AvRUeksQE&list=PLDqahtm2vA72naWj1foEqGFQiN_b...
        line='['+ii['Title']+']('+'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))+')' 
        line2='['+ii['Title']+'](./'+filename2 +')'
        
        
        
        #temp+='<tr>'+'<td>'+line2+'</td>'+'<td>'+line+'</td>'+'</tr>'
        part1='<a href="'+'./'+filename2+' "'+' target="_black"> '+ii['Title']+'</a>'
        part2='<a href="'+ 'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))  +' "'+' target="_black"> '+'YouTube'+'</a>'
        temp+='<tr>'+'<td>'+part1+'</td>'+'<td>'+part2+'</td>'+'</tr>'
        lines.append(line2)
        filenames.append(filename)
        f.write(line+'\n\n')
        f.write(text)
        f.close()
        #break

# %%
lines
# Out:
# ['[1. Katha Upanishad | Introduction | Swami Sarvapriyananda](./Video-1)',
#  '[3. Katha Upanishad | Mantras 1.1.4 - 8 | Swami Sarvapriyananda](./Video-3)',
#  '[4. Katha Upanishad | Mantras 1.1.9 - 11 | Swami Sarvapriyananda](./Video-4)',
#  '[5. Katha Upanishad | Mantras 1.1.12 - 15 | Swami Sarvapriyananda](./Video-5)',
#  '[6. Katha Upanishad | Mantras 1.1.16 - 19 | Swami Sarvapriyananda](./Video-6)',
#  '[7. Katha Upanishad | Mantra 1.1.20 | Swami Sarvapriyananda](./Video-7)',
#  '[8. Katha Upanishad | Mantras 1.1.21 - 24 | Swami Sarvapriyananda](./Video-8)',
#  '[9. Katha Upanishad | Mantras 1.1.25 - 28 | Swami Sarvapriyananda](./Video-9)',
#  '[10. Katha Upanishad | Mantras 1.1.29 - 1.2.2 | Swami Sarvapriyananda](./Video-10)',
#  '[11. Katha Upanishad | Mantras 1.2.3 - 5 | Swami Sarvapriyananda](./Video-11)',
#  '[12. Katha Upanishad | Mantras 1.2.6 - 7 | Swami Sarvapriyananda](./Video-12)',
#  '[13. Katha Upanishad | Mantras 1.2.8 - 10 | Swami Sarvapriyananda](./Video-13)',
#  '[14. Katha Upanishad | Mantras 1.2.11 - 13 | Swami Sarvapriyananda](./Video-14)',
#  '[15. Katha Upanishad | Mantras 1.2.14 - 15 | Swami Sarvapriyananda](./Video-15)',
#  '[16. Katha Upanishad | Mantras 1.2.16 - 19 | Swami Sarvapriyananda](./Video-16)',
#  '[17. Katha Upanishad | Mantra 1.2.20 | Swami Sarvapriyananda](./Video-17)',
#  '[18. Katha Upanishad | Mantras 1.2.21 - 22 | Swami Sarvapriyananda](./Video-18)',
#  '[19. Katha Upanishad | Mantras 1.2.23 - 25 | Swami Sarvapriyananda](./Video-19)',
#  '[20. Katha Upanishad | Mantra 1.3.1 | Swami Sarvapriyananda](./Video-20)',
#  '[21. Katha Upanishad | Mantras 1.3.2 - 9 | Swami Sarvapriyananda](./Video-21)',
#  '[22. Katha Upanishad | Mantras 1.3.10 - 12 | Swami Sarvapriyananda](./Video-22)',
#  '[23. Katha Upanishad | Mantra 1.3.13 | Swami Sarvapriyananda](./Video-23)',
#  '[24. Katha Upanishad | Mantras 1.3.14 - 17 | Swami Sarvapriyananda](./Video-24)',
#  '[25. Katha Upanishad | Mantras 2.1.1 - 2 | Swami Sarvapriyananda](./Video-25)',
#  '[26. Katha Upanishad | Mantra 2.1.3 | Swami Sarvapriyananda](./Video-26)',
#  '[27. Katha Upanishad | Mantras 2.1.4 - 5 | Swami Sarvapriyananda](./Video-27)',
#  '[28. Katha Upanishad | Mantras 2.1.6 - 9 | Swami Sarvapriyananda](./Video-28)',
#  '[29. Katha Upanishad | Mantra 2.1.10 | Swami Sarvapriyananda](./Video-29)',
#  '[30. Katha Upanishad | Mantras 2.1.11 - 12 | Swami Sarvapriyananda](./Video-30)',
#  '[31. Katha Upanishad | Mantras 2.1.13 - 15 | Swami Sarvapriyananda](./Video-31)',
#  '[32. Katha Upanishad | Mantra 2.2.1 | Swami Sarvapriyananda](./Video-32)',
#  '[33. Katha Upanishad | Mantras 2.2.2 - 4 | Swami Sarvapriyananda](./Video-33)',
#  '[34. Katha Upanishad | Mantras 2.2.5 - 8 | Swami Sarvapriyananda](./Video-34)',
#  '[35. Katha Upanishad | Mantras 2.2.9 - 11 | Swami Sarvapriyananda](./Video-35)',
#  '[36. Katha Upanishad | Mantras 2.2.12 | Swami Sarvapriyananda](./Video-36)',
#  '[37. Katha Upanishad | Mantras 2.2.13 - 14 | Swami Sarvapriyananda](./Video-37)',
#  '[38. Katha Upanishad | Mantra 2.2.15 | Swami Sarvapriyananda](./Video-38)',
#  '[39. Katha Upanishad | Mantra 2.3.1 | Swami Sarvapriyananda](./Video-39)',
#  '[40. Katha Upanishad | Mantras 2.3.2 - 5 | Swami Sarvapriyananda](./Video-40)',
#  '[41. Katha Upanishad | Mantras 2.3.6 - 8 | Swami Sarvapriyananda](./Video-41)',
#  '[42. Katha Upanishad | Mantras 2.3.9 - 11 | Swami Sarvapriyananda](./Video-42)',
#  '[43. Katha Upanishad | Mantras 2.3.12 - 13 | Swami Sarvapriyananda](./Video-43)',
#  '[44. Katha Upanishad | Mantras 2.3.14 - 18 | Swami Sarvapriyananda](./Video-44)']

# %%
md_path='index.md'
with open(md_path, "r") as file:
    filedata = file.read().splitlines()
content = []

content = ['\n  [Katha Upanishad](https://en.wikipedia.org/wiki/Katha_Upanishad) by [Swami Sarvapriyananda](https://en.wikipedia.org/wiki/Swami_Sarvapriyananda) \n\n<!--table_content-->\n']
# for j in filedata:
#     if "<!--table_content-->" in j:
#         content.append("<!--table_content-->")
#     else:
#         content.append(j)
with open(md_path, "w") as file:
    file.write("\n".join(content))

with open(md_path, "r") as file:
    filedata = file.read().splitlines()
    


for j in filedata:
    if "<!--table_content-->" in j:
        content.append("<!--table_content-->"+temp+"</table>")
#     else:
#         content.append(j)
        
# for i in lines:
#         temp =  "<!--table_content-->"+"<tr>"+ "<td>"+
#         "<table style="width:100%" id="j_table"><thead><tr><th>Text</th><th>Video</th></thead>"+'\n\n'.join(lines) +"</table>"
#         content.append(temp)
#     else:
#         content.append(j)
            

with open(md_path, "w") as file:
        file.write("\n".join(content))
