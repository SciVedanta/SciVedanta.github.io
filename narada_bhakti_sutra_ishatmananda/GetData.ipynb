# %%
#pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_text(youtube_id="XhKdu1_m-k4"):
    try:
        text = " ".join(
            [
                i["text"]
                .replace("\xa0\xa0", " ")
                .replace("\n", "")
                .replace("\xa0", " ")
                for i in YouTubeTranscriptApi.get_transcript(youtube_id)
            ]
        )
        return text
    except:
        print ('Failed for',youtube_id )
        pass

# %%
import pandas as pd
df = pd.read_csv('Sheet1.csv')
df = df[df['Title'].notnull()]

# %%
df['youtube_id']=df['ID'].apply(lambda x: str(x).split('&')[0].strip('!'))

# %%
from tqdm import tqdm
tqdm.pandas()
df['text'] = df['youtube_id'].progress_apply(lambda x:get_text(x))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:12<00:00,  1.17s/it]

# %%
df
# Out:
#                                              Title  \
# 0    1. Fragrance of Vedanta: Narada Bhakti Sutras
# 1    2. Fragrance of Vedanta: Narada Bhakti Sutras
# 2    3. Fragrance of Vedanta: Narada Bhakti Sutras
# 3    4. Fragrance of Vedanta: Narada Bhakti Sutras
# 4     5. Fragrance of Vedanta: Narada Bhakti Sutra
# 5   6. Fragrance of Vedanta: Narada Bhakti Sutras
# 6                           7. Narada Bhakti Sutra
# 7     9. Fragrance of Vedanta: Narada Bhakti Sutra
# 8    10. Fragrance of Vedanta: Narada Bhakti Sutra
# 9    11. Fragrance of Vedanta: Narada Bhakti Sutra
# 10   12. Fragrance of Vedanta: Narada Bhakti Sutra
#
#                                                    ID   youtube_id  \
# 0   jcq-zimIAJ8&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  jcq-zimIAJ8
# 1   SLsYjiaL7Gs&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  SLsYjiaL7Gs
# 2   iTu-yGRLD5I&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  iTu-yGRLD5I
# 3   YOUdgItedDs&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  YOUdgItedDs
# 4                                         6acTiUemo7k  6acTiUemo7k
# 5                                         X6gTSoKKvII  X6gTSoKKvII
# 6   84wW9r1DeRk&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  84wW9r1DeRk
# 7   65RvqStG_dQ&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  65RvqStG_dQ
# 8   u8W7p5Y1OvA&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  u8W7p5Y1OvA
# 9   jf2y_gGgTnw&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  jf2y_gGgTnw
# 10  tE56ifpZGzg&list=PLOEjrfhKOlHnxo4tHZunDzf6V6C4...  tE56ifpZGzg
#
#                                                  text
# 0   dear devotees and friends today this saturday ...
# 1   namaskar today the saturday morning and as the...
# 2   namaskar today we'll be studying the naradiya ...
# 3   namaskar their devotees and friends today is t...
# 4   their devotees and friends today this saturday...
# 5   namaskar good morning this is the first saturd...
# 6   namaskar good morning dear devotees and friend...
# 7   morning dear devotees and friends today is the...
# 8   namaskar good morning dear devotees and friend...
# 9   namaskar their devotees and friends today the ...
# 10  namaskar dear devotees and friends hope you ar...

# %%
lines=[]
filenames=[]
temp='<!--table_content--><table style="width:100%" id="j_table">'+ "<thead><tr>"+ "<th>Text</th>"+ "<th>Video</th>"+ "</tr></thead>"
for i,ii in df.iterrows():
    page = int(ii.name)+1  #ii['Unnamed: 0']
    text = ii['text']
    if text is not None:
        #print('text',text)
        filename='Video-'+str(page)+'.md'
        filename2='Video-'+str(page)
        #print (filename)
        f=open(filename,'w')
        line='['+ii['Title']+']('+'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))+')' 
        line2='['+ii['Title']+'](./'+filename2 +')'
        
        
        
        #temp+='<tr>'+'<td>'+line2+'</td>'+'<td>'+line+'</td>'+'</tr>'
        part1='<a href="'+'./'+filename2+' "'+' target="_black"> '+ii['Title']+'</a>'
        part2='<a href="'+ 'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))  +' "'+' target="_black"> '+'YouTube'+'</a>'
        temp+='<tr>'+'<td>'+part1+'</td>'+'<td>'+part2+'</td>'+'</tr>'
        lines.append(line2)
        filenames.append(filename)
        f.write(line+'\n\n')
        f.write(text)
        f.close()
        #break

# %%
lines
# Out:
# ['[1. Fragrance of Vedanta: Narada Bhakti Sutras](./Video-1)',
#  '[2. Fragrance of Vedanta: Narada Bhakti Sutras](./Video-2)',
#  '[3. Fragrance of Vedanta: Narada Bhakti Sutras](./Video-3)',
#  '[4. Fragrance of Vedanta: Narada Bhakti Sutras](./Video-4)',
#  '[5. Fragrance of Vedanta: Narada Bhakti Sutra](./Video-5)',
#  '[6. Fragrance of Vedanta: Narada Bhakti Sutras ](./Video-6)',
#  '[7. Narada Bhakti Sutra](./Video-7)',
#  '[9. Fragrance of Vedanta: Narada Bhakti Sutra](./Video-8)',
#  '[10. Fragrance of Vedanta: Narada Bhakti Sutra](./Video-9)',
#  '[11. Fragrance of Vedanta: Narada Bhakti Sutra](./Video-10)',
#  '[12. Fragrance of Vedanta: Narada Bhakti Sutra](./Video-11)']

# %%
md_path='index.md'
with open(md_path, "r") as file:
    filedata = file.read().splitlines()
content = []

content = ['\n [The Fragrance Of Vedanta: Narada Bhakti Sutras](https://en.wikipedia.org/wiki/Narada_Bhakti_Sutra) by [Swami Ishatmananda](https://chicagovedanta.org/swami_ishatmananda.html) \n\n<!--table_content-->\n']
# for j in filedata:
#     if "<!--table_content-->" in j:
#         content.append("<!--table_content-->")
#     else:
#         content.append(j)
with open(md_path, "w") as file:
    file.write("\n".join(content))

with open(md_path, "r") as file:
    filedata = file.read().splitlines()
    


for j in filedata:
    if "<!--table_content-->" in j:
        content.append("<!--table_content-->"+temp+"</table>")
#     else:
#         content.append(j)
        
# for i in lines:
#         temp =  "<!--table_content-->"+"<tr>"+ "<td>"+
#         "<table style="width:100%" id="j_table"><thead><tr><th>Text</th><th>Video</th></thead>"+'\n\n'.join(lines) +"</table>"
#         content.append(temp)
#     else:
#         content.append(j)
            

with open(md_path, "w") as file:
        file.write("\n".join(content))
