# %%
#pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_text(youtube_id="XhKdu1_m-k4"):
    try:
        text = " ".join(
            [
                i["text"]
                .replace("\xa0\xa0", " ")
                .replace("\n", "")
                .replace("\xa0", " ")
                for i in YouTubeTranscriptApi.get_transcript(youtube_id)
            ]
        )
        return text
    except:
        print ('Failed for',youtube_id )
        pass

# %%
import pandas as pd
df = pd.read_csv('Sheet1.csv')
df = df[df['Title'].notnull()]

# %%
df['youtube_id']=df['ID'].apply(lambda x: str(x).split('&')[0].strip('!'))

# %%
from tqdm import tqdm
tqdm.pandas()
df['text'] = df['youtube_id'].progress_apply(lambda x:get_text(x))
# Out:
#  22%|█████████████████████████████████████▍                                                                                                                                       | 26/120 [00:42<01:37,  1.04s/it]
# Failed for 1MlCoSiXwU
#  65%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                            | 78/120 [01:51<00:43,  1.04s/it]
# Failed for Xr3XVlgZXmw
#  67%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                         | 80/120 [01:53<00:42,  1.05s/it]
# Failed for exAcdd7ZuFg
#  68%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                      | 82/120 [01:55<00:37,  1.02it/s]
# Failed for 28VJr6TSkYo
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 120/120 [02:41<00:00,  1.35s/it]

# %%
df
# Out:
#                                                  Title  \
# 0    1. Bhagavad Gita | Chapter 1 Summary | Swami S...
# 1    2. Bhagavad Gita | Chapter 2 Verses 1-10 | Swa...
# 2    3. Bhagavad Gita | Chapter 2 Verses 11-12 | Sw...
# 3    4. Bhagavad Gita | Chapter 2 Verses 13-15 | Sw...
# 4    5. Bhagavad Gita | Chapter 2 Verse 16 | Swami ...
# ..                                                 ...
# 115  116. Bhagavad Gita | Chapter 9 Verses 32-34 | ...
# 116  117. Bhagavad Gita | Chapter 9 Verse 34 Revisi...
# 117  118. Bhagavad Gita | Chapter 10 Verse 1-3 | Sw...
# 118  119. Bhagavad Gita | Chapter 10 Verse 4-6 | Sw...
# 119  120. Bhagavad Gita | Chapter 10 Verse 7-9 | Sw...
#
#                                                     ID   youtube_id  \
# 0    y9Kt7Db9MxA&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  y9Kt7Db9MxA
# 1    6HuD2JJzzjs&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  6HuD2JJzzjs
# 2    rB1qNzSeB7c&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  rB1qNzSeB7c
# 3    QD6PMVBDrZ4&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  QD6PMVBDrZ4
# 4    XDPmbom12wM&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  XDPmbom12wM
# ..                                                 ...          ...
# 115  3O_8JVNJL6g&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  3O_8JVNJL6g
# 116  jQby6wweMZA&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  jQby6wweMZA
# 117  A1mC3_TNFNQ&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  A1mC3_TNFNQ
# 118  qMDSCVb5HJQ&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  qMDSCVb5HJQ
# 119  kW2FZbEB1LI&list=PL2imXor63HtS4ewIKryBL4ZVeiaH...  kW2FZbEB1LI
#
#                                                   text
# 0    vasudeva's suitum deivam come such our new ram...
# 1    Ghita and I made some introductory remarks abo...
# 2    Oh Vasu deeper Suton daivam come search our ne...
# 3    vasudeva's suitum daivam comes as our new deni...
# 4    Oh Vasudeva suitum our new Ramadan um dave aqu...
# ..                                                 ...
# 115  Guru so we are studying the bhagavad-gita and ...
# 116  Guru so the last verse of the ninth chapter we...
# 117  um vasudeva sutam devam comes [Music] so we ha...
# 118  um blessude was [Music] krishnam one day study...
# 119  oh was Guru [Music] so beyond the tenth chapte...
#
# [120 rows x 4 columns]

# %%
lines=[]
filenames=[]
temp='<!--table_content--><table style="width:100%" id="j_table">'+ "<thead><tr>"+ "<th>Text</th>"+ "<th>Video</th>"+ "</tr></thead>"
for i,ii in df.iterrows():
    page = int(ii.name)+1  #ii['Unnamed: 0']
    text = ii['text']
    if text is not None:
        #print('text',text)
        filename='Video-'+str(page)+'.md'
        filename2='Video-'+str(page)
        #print (filename)
        f=open(filename,'w')
        line='['+ii['Title']+']('+'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))+')' 
        line2='['+ii['Title']+'](./'+filename2 +')'
        
        
        
        #temp+='<tr>'+'<td>'+line2+'</td>'+'<td>'+line+'</td>'+'</tr>'
        part1='<a href="'+'./'+filename2+' "'+' target="_black"> '+ii['Title']+'</a>'
        part2='<a href="'+ 'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))  +' "'+' target="_black"> '+'YouTube'+'</a>'
        temp+='<tr>'+'<td>'+part1+'</td>'+'<td>'+part2+'</td>'+'</tr>'
        lines.append(line2)
        filenames.append(filename)
        f.write(line+'\n\n')
        f.write(text)
        f.close()
        #break

# %%
lines
# Out:
# ['[1. Bhagavad Gita | Chapter 1 Summary | Swami Sarvapriyananda](./Video-1)',
#  '[2. Bhagavad Gita | Chapter 2 Verses 1-10 | Swami Sarvapriyananda](./Video-2)',
#  '[3. Bhagavad Gita | Chapter 2 Verses 11-12 | Swami Sarvapriyananda](./Video-3)',
#  '[4. Bhagavad Gita | Chapter 2 Verses 13-15 | Swami Sarvapriyananda](./Video-4)',
#  '[5. Bhagavad Gita | Chapter 2 Verse 16 | Swami Sarvapriyananda](./Video-5)',
#  '[6. Bhagavad Gita | Chapter 2 Verses 17-18 | Swami Sarvapriyananda](./Video-6)',
#  '[7. Bhagavad Gita I Chapter 2 Verse 19 I Swami Sarvapriyananda](./Video-7)',
#  '[8. Bhagavad Gita I Chapter 2 Verses 20-22 I Swami Sarvapriyananda](./Video-8)',
#  '[9. Bhagavad Gita I Chapter 2 Verses 23-25 I Swami Sarvapriyananda](./Video-9)',
#  '[10. Bhagavad Gita I Chapter 2 Verses 26-27 I Swami Sarvapriyananda](./Video-10)',
#  '[11. Bhagavad Gita I Chapter 2 Verses 28-29 I Swami Sarvapriyananda](./Video-11)',
#  '[102. Bhagavad Gita | Chapter 8 Verses 15-20 | Swami Sarvapriyananda](./Video-102)',
#  '[103. Bhagavad Gita | Chapter 8 Verses 21-22 | Swami Sarvapriyananda](./Video-103)',
#  '[104. Bhagavad Gita | Chapter 8 Verses 23-28 | Swami Sarvapriyananda](./Video-104)',
#  '[105. Bhagavad Gita | Chapter 9 Verses 1-2 | Swami Sarvapriyananda](./Video-105)',
#  '[106. Bhagavad Gita | Chapter 9 Verses 3-4 | Swami Sarvapriyananda](./Video-106)',
#  '[107. Bhagavad Gita | Chapter 9 Verses 5-8 | Swami Sarvapriyananda](./Video-107)',
#  '[108. Bhagavad Gita | Chapter 9 Verses 9-13 | Swami Sarvapriyananda](./Video-108)',
#  '[109. Bhagavad Gita | Chapter 9 Verse 14 | Swami Sarvapriyananda](./Video-109)',
#  '[110. Bhagavad Gita | Chapter 9 Verses 15-16 | Swami Sarvapriyananda](./Video-110)',
#  '[111. Bhagavad Gita | Chapter 9 Verse 17 | Swami Sarvapriyananda](./Video-111)',
#  '[112. Bhagavad Gita | Chapter 9 Verses 18-21 | Swami Sarvapriyananda](./Video-112)',
#  '[113. Bhagavad Gita | Chapter 9 Verses 22-25 | Swami Sarvapriyananda](./Video-113)',
#  '[114. Bhagavad Gita | Chapter 9 Verses 26-28 | Swami Sarvapriyananda](./Video-114)',
#  '[115. Bhagavad Gita | Chapter 9 Verses 29-31 | Swami Sarvapriyananda](./Video-115)',
#  '[116. Bhagavad Gita | Chapter 9 Verses 32-34 | Swami Sarvapriyananda](./Video-116)',
#  '[117. Bhagavad Gita | Chapter 9 Verse 34 Revision | Swami Sarvapriyananda](./Video-117)',
#  '[118. Bhagavad Gita | Chapter 10 Verse 1-3 | Swami Sarvapriyananda](./Video-118)',
#  '[119. Bhagavad Gita | Chapter 10 Verse 4-6 | Swami Sarvapriyananda](./Video-119)',
#  '[120. Bhagavad Gita | Chapter 10 Verse 7-9 | Swami Sarvapriyananda](./Video-120)']

# %%
md_path='index.md'
with open(md_path, "r") as file:
    filedata = file.read().splitlines()
content = []

content = ['\n [The Bhagavad Gita](https://en.wikipedia.org/wiki/Bhagavad_Gita) by [Swami Sarvapriyananda](https://en.wikipedia.org/wiki/Swami_Sarvapriyananda) \n\n<!--table_content-->\n']
# for j in filedata:
#     if "<!--table_content-->" in j:
#         content.append("<!--table_content-->")
#     else:
#         content.append(j)
with open(md_path, "w") as file:
    file.write("\n".join(content))

with open(md_path, "r") as file:
    filedata = file.read().splitlines()
    


for j in filedata:
    if "<!--table_content-->" in j:
        content.append("<!--table_content-->"+temp+"</table>")
#     else:
#         content.append(j)
        
# for i in lines:
#         temp =  "<!--table_content-->"+"<tr>"+ "<td>"+
#         "<table style="width:100%" id="j_table"><thead><tr><th>Text</th><th>Video</th></thead>"+'\n\n'.join(lines) +"</table>"
#         content.append(temp)
#     else:
#         content.append(j)
            

with open(md_path, "w") as file:
        file.write("\n".join(content))
