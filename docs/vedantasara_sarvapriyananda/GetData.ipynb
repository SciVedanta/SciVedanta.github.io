# %%
#pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_text(youtube_id="XhKdu1_m-k4"):
    try:
        text = " ".join(
            [
                i["text"]
                .replace("\xa0\xa0", " ")
                .replace("\n", "")
                .replace("\xa0", " ")
                for i in YouTubeTranscriptApi.get_transcript(youtube_id)
            ]
        )
        return text
    except:
        print ('Failed for',youtube_id )
        pass

# %%
import pandas as pd
df = pd.read_csv('Sheet1.csv')
df = df[df['Title'].notnull()]

# %%
df['youtube_id']=df['ID'].apply(lambda x: str(x).split('&')[0].strip('!'))

# %%
from tqdm import tqdm
tqdm.pandas()
df['text'] = df['youtube_id'].progress_apply(lambda x:get_text(x))
# Out:
#   8%|██████████████▏                                                                                                                                                                | 3/37 [00:02<00:25,  1.33it/s]
# Failed for s29nQIcvMkg
#  24%|██████████████████████████████████████████▌                                                                                                                                    | 9/37 [00:09<00:28,  1.02s/it]
# Failed for UkjMTrOQf5Y
#  32%|████████████████████████████████████████████████████████▍                                                                                                                     | 12/37 [00:12<00:26,  1.06s/it]
# Failed for WnoWinbZvhI
#  49%|████████████████████████████████████████████████████████████████████████████████████▋                                                                                         | 18/37 [00:19<00:19,  1.03s/it]
# Failed for Xli2KOcbLQU
#  57%|██████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                           | 21/37 [00:22<00:15,  1.03it/s]
# Failed for BCoCohzfT68
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 36/37 [00:40<00:01,  1.08s/it]
# Failed for LLctfri5GsI
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37/37 [00:41<00:00,  1.02it/s]
# Failed for xbLR-LL2eJc
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37/37 [00:42<00:00,  1.15s/it]

# %%
df
# Out:
#                                                 Title  \
# 0     1. Vedantasara | Text 1 | Swami Sarvapriyananda
# 1   2. Vedantasara | Texts 2-5 | Swami Sarvapriyan...
# 2   3. Vedantasara | Texts 5-15 | Swami Sarvapriya...
# 3   4. Vedantasara | Texts 16-26 | Swami Sarvapriy...
# 4   5. Vedantasara | Texts 27-29 | Swami Sarvapriy...
# 5   6. Vedantasara | Texts 30-32 | Swami Sarvapriy...
# 6   7. Vedantasara | Texts 33-34 | Swami Sarvapriy...
# 7   8. Vedantasara | Texts 35-39 | Swami Sarvapriy...
# 8   9. Vedantasara | Texts 40-46 | Swami Sarvapriy...
# 9   10. Vedantasara | Texts 47-50 | Swami Sarvapri...
# 10  11. Vedantasara | Texts 51-53 | Swami Sarvapri...
# 11  12. Vedantasara | Texts 54-56 | Swami Sarvapri...
# 12  13. Vedantasara | Texts 57-60 | Swami Sarvapri...
# 13  14. Vedantasara | Texts 61-74 | Swami Sarvapri...
# 14  15. Vedantasara | Texts 75-91 | Swami Sarvapri...
# 15  16. Vedantasara | Texts 92-97 | Swami Sarvapri...
# 16  17. Vedantasara | Texts 98-109 | Swami Sarvapr...
# 17  18. Vedantasara | Texts 110-121 | Swami Sarvap...
# 18  19. Vedantasara | Texts 122-127 | Swami Sarvap...
# 19  20. Vedantasara | Text 128 | Swami Sarvapriyan...
# 20  21. Vedantasara | Texts 129-131 | Swami Sarvap...
# 21  22. Vedantasara | Shunyavada Buddhism | Swami ...
# 22  23. Vedantasara | Texts 132-136 | Swami Sarvap...
list=PLDqahtm2vA70ccqIRFR_lipqKvxr...  xbLR-LL2eJc
# 36  JbWuVzwJP90&list=PLDqahtm2vA70ccqIRFR_lipqKvxr...  JbWuVzwJP90
#
#                                                  text
# 0   from the unreal to the real lead us from darkn...
# 1                                                None
# 2   [Music] so namaste everybody um we are studyin...
# 3   [Music] so we have been studying the vedanta s...
# 4   [Music] so we are studying the uh vedanta sara...
# 5   [Music] so we are studying the vedanta and i b...
# 6   so good evening and namaste everybody we are s...
# 7                                                None
# 8   [Music] we were on text number 40 39 we turn u...
# 9   we have been studying the let us say the abcd ...
# 10                                               None
# 11  [Music] [Music] i take refuge in the self the ...
# 12  [Music] i take refuge in the self which is ind...
# 13  i take refuge in the self the indivisible the ...
# 14  [Music] so we are studying the vedanta sarah a...
# 15  [Music] [Music] the self the indivisible exist...
# 16                                               None
# 17  i take refuge in the self the indivisible exis...
# 18  [Music] [Music] i take refuge in the self the ...
# 19                                               None
# 20  [Music] i take refuge in the atman the indivis...
# 21  [Music] [Music] i take refuge in the self the ...
# 22  [Music] i take refuge in the self the indivisi...
# 23  [Music] i take refuge in the self the indivisi...
# 24  i take refuge in the self the indivisible the ...
# 25  [Music] i take refuge in the self the indivisi...
# 26  [Music] i take refuge in the self the indivisi...
# 27  [Music] i take refuge in the self the indivisi...
# 28  [Music] i take refuge as the self the indivisi...
# 29  [Music] i take refuge in the self the indivisi...
# 30  [Music] m i take refuge in the self the indivi...
# 31  [Music] i take refuge in the self the indivisi...
# 32  [Music] i take refuge in the self the indivisi...
# 33  [Music] [Music] i take refuge in the self the ...
# 34                                               None
# 35                                               None
# 36  [Music] [Music] i take refuge in the self the ...

# %%
lines=[]
filenames=[]
temp='<!--table_content--><table style="width:100%" id="j_table">'+ "<thead><tr>"+ "<th>Text</th>"+ "<th>Video</th>"+ "</tr></thead>"
for i,ii in df.iterrows():
    page = int(ii.name)+1  #ii['Unnamed: 0']
    text = ii['text']
    if text is not None:
        #print('text',text)
        filename='Video-'+str(page)+'.md'
        filename2='Video-'+str(page)
        #print (filename)
        f=open(filename,'w')
        line='['+ii['Title']+']('+'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))+')' 
        line2='['+ii['Title']+'](./'+filename2 +')'
        
        
        
        #temp+='<tr>'+'<td>'+line2+'</td>'+'<td>'+line+'</td>'+'</tr>'
        part1='<a href="'+'./'+filename2+' "'+' target="_black"> '+ii['Title']+'</a>'
        part2='<a href="'+ 'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))  +' "'+' target="_black"> '+'YouTube'+'</a>'
        temp+='<tr>'+'<td>'+part1+'</td>'+'<td>'+part2+'</td>'+'</tr>'
        lines.append(line2)
        filenames.append(filename)
        f.write(line+'\n\n')
        f.write(text)
        f.close()
        #break

# %%
lines
# Out:
# ['[1. Vedantasara | Text 1 | Swami Sarvapriyananda](./Video-1)',
#  '[3. Vedantasara | Texts 5-15 | Swami Sarvapriyananda](./Video-3)',
#  '[4. Vedantasara | Texts 16-26 | Swami Sarvapriyananda](./Video-4)',
#  '[5. Vedantasara | Texts 27-29 | Swami Sarvapriyananda](./Video-5)',
#  '[6. Vedantasara | Texts 30-32 | Swami Sarvapriyananda](./Video-6)',
#  '[7. Vedantasara | Texts 33-34 | Swami Sarvapriyananda](./Video-7)',
#  '[9. Vedantasara | Texts 40-46 | Swami Sarvapriyananda](./Video-9)',
#  '[10. Vedantasara | Texts 47-50 | Swami Sarvapriyananda](./Video-10)',
#  '[12. Vedantasara | Texts 54-56 | Swami Sarvapriyananda](./Video-12)',
#  '[13. Vedantasara | Texts 57-60 | Swami Sarvapriyananda](./Video-13)',
#  '[14. Vedantasara | Texts 61-74 | Swami Sarvapriyananda](./Video-14)',
#  '[15. Vedantasara | Texts 75-91 | Swami Sarvapriyananda](./Video-15)',
#  '[16. Vedantasara | Texts 92-97 | Swami Sarvapriyananda](./Video-16)',
#  '[18. Vedantasara | Texts 110-121 | Swami Sarvapriyananda](./Video-18)',
#  '[19. Vedantasara | Texts 122-127 | Swami Sarvapriyananda](./Video-19)',
#  '[21. Vedantasara | Texts 129-131 | Swami Sarvapriyananda](./Video-21)',
#  '[22. Vedantasara | Shunyavada Buddhism | Swami Sarvapriyananda](./Video-22)',
#  '[23. Vedantasara | Texts 132-136 | Swami Sarvapriyananda](./Video-23)',
#  '[24. Vedantasara | Texts 137-143 | Swami Sarvapriyananda](./Video-24)',
#  '[25. Vedantasara | Texts 144-150 | Swami Sarvapriyananda](./Video-25)',
#  '[26. Vedantasara | Texts 151-152 | Swami Sarvapriyananda](./Video-26)',
#  '[27. Vedantasara | Texts 153-158 | Swami Sarvapriyananda](./Video-27)',
#  '[28. Vedantasara | Texts 159-169 | Swami Sarvapriyananda](./Video-28)',
#  '[29. Vedantasara | Texts 170-171 | Swami Sarvapriyananda](./Video-29)',
#  '[30. Vedantasara | Text 172 | Swami Sarvapriyananda](./Video-30)',
#  '[31. Vedantasara | Texts 173-180 | Swami Sarvapriyananda](./Video-31)',
#  '[32. Vedantasara | Texts 181-190 | Swami Sarvapriyananda](./Video-32)',
#  '[33. Vedantasara | Texts 191-192 | Swami Sarvapriyananda](./Video-33)',
#  '[34. Vedantasara | Texts 193-198 | Swami Sarvapriyananda](./Video-34)',
#  '[37. Vedantasara | Texts 220-227 | Swami Sarvapriyananda](./Video-37)']

# %%
md_path='index.md'
with open(md_path, "r") as file:
    filedata = file.read().splitlines()
content = []

content = ['\n  [Vedantasara](https://en.wikipedia.org/wiki/Vedantasara_(of_Sadananda) by [Swami Sarvapriyananda](https://en.wikipedia.org/wiki/Swami_Sarvapriyananda) \n\n<!--table_content-->\n']
# for j in filedata:
#     if "<!--table_content-->" in j:
#         content.append("<!--table_content-->")
#     else:
#         content.append(j)
with open(md_path, "w") as file:
    file.write("\n".join(content))

with open(md_path, "r") as file:
    filedata = file.read().splitlines()
    


for j in filedata:
    if "<!--table_content-->" in j:
        content.append("<!--table_content-->"+temp+"</table>")
#     else:
#         content.append(j)
        
# for i in lines:
#         temp =  "<!--table_content-->"+"<tr>"+ "<td>"+
#         "<table style="width:100%" id="j_table"><thead><tr><th>Text</th><th>Video</th></thead>"+'\n\n'.join(lines) +"</table>"
#         content.append(temp)
#     else:
#         content.append(j)
            

with open(md_path, "w") as file:
        file.write("\n".join(content))
