# %%
#pip install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_text(youtube_id="XhKdu1_m-k4"):
    try:
        text = " ".join(
            [
                i["text"]
                .replace("\xa0\xa0", " ")
                .replace("\n", "")
                .replace("\xa0", " ")
                for i in YouTubeTranscriptApi.get_transcript(youtube_id)
            ]
        )
        return text
    except:
        print ('Failed for',youtube_id )
        pass

# %%
import pandas as pd
df = pd.read_csv('Sheet1.csv')
df = df[df['Title'].notnull()]

# %%
df['youtube_id']=df['ID'].apply(lambda x: str(x).split('&')[0].strip('!'))

# %%
from tqdm import tqdm
tqdm.pandas()
df['text'] = df['youtube_id'].progress_apply(lambda x:get_text(x))
# Out:
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋    | 39/40 [00:46<00:01,  1.05s/it]
# Failed for AN9onLc3pQY
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:47<00:00,  1.02it/s]
# Failed for JGKrAEJ-DbQ
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:48<00:00,  1.21s/it]
# Failed for KhZgI4u6VZA

# %%
df
# Out:
#                                                 Title  \
# 0   Ask Swami with Swami Sarvapriyananda | Mar 5th...
# 1   Ask Swami with Swami Sarvapriyananda | Feb 26t...
# 2   Ask Swami with Swami Sarvapriyananda | Jan 22n...
# 3   Ask Swami with Swami Sarvapriyananda | June 5t...
# 4   Ask Swami with Swami Sarvapriyananda | Apr 10t...
# 5   Ask Swami with Swami Sarvapriyananda | Feb 27t...
# 6   Ask Swami with Swami Sarvapriyananda | Jan 23r...
# 7   Ask Swami with Swami Sarvapriyananda | Dec 19t...
# 8   Ask Swami with Swami Sarvapriyananda | Nov 7th...
# 9   Ask Swami with Swami Sarvapriyananda | Oct 24t...
# 10  Ask Swami with Swami Sarvapriyananda | June 13...
# 11  Ask Swami with Swami Sarvapriyananda | Februar...
# 12  Ask Swami with Swami Sarvapriyananda | January...
# 13  Ask Swami with Swami Sarvapriyananda | Decembe...
# 14  Ask Swami with Swami Sarvapriyananda | Novembe...
# 15  Ask Swami with Swami Sarvapriyananda | October...
# 16  Ask Swami with Swami Sarvapriyananda | June 28...
# 17  Ask Swami with Swami Sarvapriyananda | June 7t...
# 18  Ask Swami with Swami Sarvapriyananda | May 3rd...
# 19  Ask Swami with Swami Sarvapriyananda | Februar...
# 20  Realization (Questions & Answers) | Swami Sarv...
# 21  Ask Swami with Swami Sarvapriyananda | June 2n...
# 22  Ask Swami with Swami Sarvapriyananda | May 5th...
# 23  Ask Swami with Swami Sarvapriyananda | April 7...
# 24  Ask Swami with Swami Sarvapriyananda | March 1...
# 25  Ask Swami with Swami Sarvapriyananda | January...
# 26  Ask Swami with Swami Sarvapriyananda | Sept 30...
# 27  Ask Swami with Swami Sarvapriyananda | June 24...
# 28  Ask Swami with Swami Sarvapriyananda | May 27t...
list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  p1S4aKCigi0
# 33  YLSRvatqLFY&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  YLSRvatqLFY
# 34  l_vmlYMfsdQ&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  l_vmlYMfsdQ
# 35  bkAHtnltX-8&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  bkAHtnltX-8
# 36  C4lBgdHaYi4&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  C4lBgdHaYi4
# 37  AN9onLc3pQY&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  AN9onLc3pQY
# 38  JGKrAEJ-DbQ&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  JGKrAEJ-DbQ
# 39  KhZgI4u6VZA&list=PLDqahtm2vA70VohJ__IobJSOGFJ2...  KhZgI4u6VZA
#
#                                                  text
# 0   [Music] foreign [Music] [Music] [Music] lead u...
# 1   [Music] foreign [Music] [Music] lead us from [...
# 2   [Music] foreign [Music] all leaders from the u...
# 3   [Music] so where this works is diane is going ...
# 4   [Music] [Music] lead us from the unreal to the...
# 5   [Music] lead us from the unreal to the real le...
# 6   [Music] lead us from the unreal to the real le...
# 7   [Music] lead us from the unreal to the real le...
# 8   [Music] [Music] [Music] lead us from the unrea...
# 9   [Music] oh lead me from the unreal to the real...
# 10  [Music] oh lead us from the unreal to the real...
# 11  [Music] [Music] [Music] lead us from the unrea...
# 12  [Music] lead us from the unreal to the real le...
# 13  [Music] [Music] lead us from the unreal to the...
# 14  [Music] [Music] lead us from the unreal to the...
# 15  [Music] [Music] from the unreal to the real le...
# 16  [Music] you [Music] Oh assert oma saga Maya Th...
# 17  [Music] esatto mas at gamma yah Thomas oh ma J...
# 18  [Music] oh lead us from the unreal to the real...
# 19  [Music] Oh Misato Mossad gamma yah Thomas oh m...
# 20  [Music] so the question is if the body dies at...
# 21  [Music] a question on consciousness from Nandi...
# 22  [Music] so we have several questions on consci...
# 23  [Music] Swami Vivekananda said what we need to...
# 24  [Music] we had a lot of questions on the back ...
# 25  [Music] so this session is the ask Swamy sessi...
# 26  [Music] and remember it's not his question or ...
# 27  first we shall take some questions from the in...
# 28  we are going to have an impromptu session of o...
# 29  I think we'll start with questions from our vi...
# 30  so now we go into our monthly episode of ask S...
# 31  so now we will we are going into the recession...
# 32  now my questions which come in from the our in...
# 33  I remember about 12 years back I was in the Hi...
# 34  we will first stake questions some questions w...
# 35  so we have questions from across the world tho...
# 36  so this we also have the asks one we get quest...
# 37                                               None
# 38                                               None
# 39                                               None

# %%
lines=[]
filenames=[]
temp='<!--table_content--><table style="width:100%" id="j_table">'+ "<thead><tr>"+ "<th>Text</th>"+ "<th>Video</th>"+ "</tr></thead>"
for i,ii in df.iterrows():
    page = int(ii.name)+1  #ii['Unnamed: 0']
    text = ii['text']
    if text is not None:
        #print('text',text)
        filename='Video-'+str(page)+'.md'
        filename2='Video-'+str(page)
        #print (filename)
        f=open(filename,'w')
        line='['+ii['Title']+']('+'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))+')' 
        line2='['+ii['Title']+'](./'+filename2 +')'
        
        
        
        #temp+='<tr>'+'<td>'+line2+'</td>'+'<td>'+line+'</td>'+'</tr>'
        part1='<a href="'+'./'+filename2+' "'+' target="_black"> '+ii['Title']+'</a>'
        part2='<a href="'+ 'https://www.youtube.com/watch?v='+str(ii['ID'].split('&')[0].strip('!'))  +' "'+' target="_black"> '+'YouTube'+'</a>'
        temp+='<tr>'+'<td>'+part1+'</td>'+'<td>'+part2+'</td>'+'</tr>'
        lines.append(line2)
        filenames.append(filename)
        f.write(line+'\n\n')
        f.write(text)
        f.close()
        #break

# %%
lines
# Out:
# ['[Introduction to Vedanta Part 1 - Swami Sarvapriyananda - January 12 2016](./Video-1)',
#  '[Introduction to Vedanta Part 2 - Swami Sarvapriyananda - January 19, 2016](./Video-2)',
#  '[Introduction to Vedanta Part 3 - Swami Sarvapriyananda - February 02 2016](./Video-3)',
#  '[Introduction to Vedanta Part 4 - Swami Sarvapriyananda - February 16 2016](./Video-4)',
#  '[Introduction to Vedanta Part 5 - Swami Sarvapriyananda - March 15, 2016](./Video-5)',
#  '[Introduction to Vedanta Part 7 - Swami Sarvapriyananda - April 19, 2016](./Video-7)',
#  '[Introduction to Vedanta Part 8 - Swami Sarvapriyananda - April 26, 2016](./Video-8)',
#  '[Introduction to Vedanta Part 9 - Swami Sarvapriyananda - May 17, 2016](./Video-9)',
#  '[Introduction to Vedanta Part 10 - Swami Sarvapriyananda - May 24, 2016](./Video-10)',
#  '[Introduction to Vedanta Part 11 - Swami Sarvapriyananda - June 21, 2016](./Video-11)',
#  '[Introduction to Vedanta Part 12 (Final) - Swami Sarvapriyananda - June 28 2016](./Video-12)']

# %%
md_path='index.md'
with open(md_path, "r") as file:
    filedata = file.read().splitlines()
content = []

content = ['\n [Ask Swami Q&A by](https://www.vedantany.org/ask-swami) by [Swami Sarvapriyananda](https://en.wikipedia.org/wiki/Swami_Sarvapriyananda) \n\n<!--table_content-->\n']
# for j in filedata:
#     if "<!--table_content-->" in j:
#         content.append("<!--table_content-->")
#     else:
#         content.append(j)
with open(md_path, "w") as file:
    file.write("\n".join(content))

with open(md_path, "r") as file:
    filedata = file.read().splitlines()
    


for j in filedata:
    if "<!--table_content-->" in j:
        content.append("<!--table_content-->"+temp+"</table>")
#     else:
#         content.append(j)
        
# for i in lines:
#         temp =  "<!--table_content-->"+"<tr>"+ "<td>"+
#         "<table style="width:100%" id="j_table"><thead><tr><th>Text</th><th>Video</th></thead>"+'\n\n'.join(lines) +"</table>"
#         content.append(temp)
#     else:
#         content.append(j)
            

with open(md_path, "w") as file:
        file.write("\n".join(content))
